# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including matplotlib and seaborn.

# %%
# Import Required Libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
spi_df = pd.read_csv('Codes/spi_results.csv')
spi_df.head()
# Out:
#    station_id station_name region_id region_name     lat     lon  \
# 0       40708      Ardebil      OITL     Ardebil  38.219  48.329
# 1       40708      Ardebil      OITL     Ardebil  38.219  48.329
# 2       40708      Ardebil      OITL     Ardebil  38.219  48.329
# 3       40708      Ardebil      OITL     Ardebil  38.219  48.329
# 4       40708      Ardebil      OITL     Ardebil  38.219  48.329
#
#    station_elevation                  data    tmax_m  tmax_max  ...  tmin_min  \
# 0             1335.2  1/1/1990 12:00:00 AM -2.290320       5.8  ...     -29.0
# 1             1335.2  1/1/1991 12:00:00 AM -0.935484       5.6  ...     -24.0
# 2             1335.2  1/1/1992 12:00:00 AM -0.870000       4.8  ...     -22.5
# 3             1335.2  1/1/1993 12:00:00 AM -1.096770       8.0  ...     -25.0
# 4             1335.2  1/1/1994 12:00:00 AM  4.093330      10.0  ...     -15.2
#
#    tmin_max  ntmin_0  rrr24   sshn     tm_m    t_03_m    t_09_m    t_15_m  \
# 0      -4.0       25  50.00   64.9 -9.78400 -12.26670 -5.026670 -7.133330
# 1      -6.6       24  15.82  111.6 -7.61250  -9.58710 -3.846670 -4.361290
# 2      -2.4       27  14.23  144.4 -6.70769  -8.83226 -3.129030 -4.529030
# 3       4.4       26  30.54  114.6 -7.30000  -9.49032 -3.546670 -4.773330
# 4       0.0       24  12.65    NaN -2.29565  -5.44516 -0.103226  0.464516
#
#         SPI
# 0  0.798122
# 1 -0.264957
# 2 -0.320786
# 3  0.278863
# 4 -0.374573
#
# [5 rows x 22 columns]

# %% [markdown]
# # Define Functions
# Define the functions used in the code.

# %%
def plot_spi(station_id, spi_df):
    """
    Plot the Standardized Precipitation Index (SPI) for a specific station.
    
    Parameters:
    station_id (int): The ID of the station to plot.
    spi_df (DataFrame): DataFrame containing SPI values.
    """
    station_data = spi_df[spi_df['station_id'] == station_id]
    plt.figure(figsize=(10, 6))
    plt.plot(station_data['data'], station_data['SPI'], marker='o', linestyle='-')
    plt.title(f'SPI for Station {station_id}')
    plt.xlabel('Date')
    plt.ylabel('SPI')
    plt.grid(True)
    plt.show()

def plot_drought_heatmap(spi_df):
    """
    Plot a heatmap of drought conditions based on SPI values.
    
    Parameters:
    spi_df (DataFrame): DataFrame containing SPI values.
    """
    pivot_table = spi_df.pivot_table(index='data', columns='station_id', values='SPI')
    plt.figure(figsize=(12, 8))
    sns.heatmap(pivot_table, cmap='RdYlBu_r', center=0, annot=False, cbar_kws={'label': 'SPI'})
    plt.title('Drought Conditions Heatmap')
    plt.xlabel('Station ID')
    plt.ylabel('Month')
    plt.show()

# %% [markdown]
# # plot_spi Function
# Define the plot_spi function to plot SPI for a specific station.

# %%
# Example: Plot SPI for a Specific Station
plot_spi(station_id=40708, spi_df=spi_df)

# %%
# Generate Heatmap
plot_drought_heatmap(spi_df)
